# %% [markdown]
# # Here we are going to study many of the data gathering technique

# %% [markdown]
# # The First and most common is getting data from the csv

# %%
#getting data from the csv from local file 
import pandas as pd 
df = pd.read.csv('example.csv') # this is done if seperator is , if not then see below 
df = pd.read.csv('example2.csv' , sep="\t") # if tab seperated similarly for other seperator

# %% [markdown]
# # Second is getting data from JSON

# %%
import pandas as pd
pd.read_json('example.json')

# %% [markdown]
# # Third is getting data from SQL
